# %% [markdown]
#  # Practica 3: Logistic Regression
#
#  Code by: Amparo Rubio Bellon y Jorge Zurdo Izquierdo

# %%
import numpy as np
import matplotlib.pyplot as plt

import utils as util
import public_tests as pt
import logistic_reg as lr

X,y= util.load_data("data/ex2data1.txt", ',')
w=np.zeros(X.shape[1])
b=-8
alpha=0.001
num_iterations=100000

w_opt,b_opt,cost=lr.gradient_descent(X, y, w, b, lr.compute_cost, lr.compute_gradient, alpha, num_iterations)


util.plot_decision_boundary(w_opt,b_opt,X,y)

# %%
import numpy as np
import matplotlib.pyplot as plt

import utils as util
import public_tests as pt
import logistic_reg as lr

X,y= util.load_data("data/ex2data2.txt", ',')
w=np.zeros(X.shape[1])
b=-8
alpha=0.001
num_iterations=100000

Z=util.map_feature(X[0],X[1])
w_opt,b_opt=lr.compute_gradient_reg(Z, y, w, b)


util.plot_decision_boundary(w_opt,b_opt,X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 15
#      12 num_iterations=100000
#      14 Z=util.map_feature(X[0],X[1])
# ---> 15 w_opt,b_opt=lr.compute_gradient_reg(Z, y, w, b)
#      18 util.plot_decision_boundary(w_opt,b_opt,X,y)
#
# File ~\Documents\Universidad\Aprendizaje-Automatico\Practicas\Practica3\logistic_reg.py:126, in compute_gradient_reg(X, y, w, b, lambda_)
#     123 m = len(y)  # Number of training examples
#     125 # Compute the predictions
# --> 126 z = np.dot(X, w) + b
#     127 y_pred = sigmoid(z)
#     129 # Compute the gradient with respect to b
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# ValueError: shapes (2,27) and (2,) not aligned: 27 (dim 1) != 2 (dim 0)

# %% [markdown]
# ## Practica 5:  Amparo Rubio Bellon y Jorge Zurdo Izquierdo

# %%
import numpy as np
from scipy.io import loadmat
import ann


# Constants
input_size = 400
hidden_size = 25
output_size = 10
lambda_ = 1
alpha = 1
num_iterations = 1000
# Load data
data = loadmat('data/ex3data1.mat', squeeze_me=True)
X = data['X']
y = data['y']

# Train the neural network
theta1, theta2 = ann.train_neural_network(X, y, input_size, hidden_size, output_size, lambda_, alpha, num_iterations)

# Make predictions on training set
predictions = ann.predict(theta1, theta2, X)

# Calculate accuracy
accuracy = np.mean(predictions == y.flatten()) * 100
print(accuracy)
# Out:
# C:\Users\ampxr\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 19
#      16 y = data['y']
#      18 # Train the neural network
# ---> 19 theta1, theta2 = ann.train_neural_network(X, y, input_size, hidden_size, output_size, lambda_, alpha, num_iterations)
#      21 # Make predictions on training set
#      22 predictions = ann.predict(theta1, theta2, X)
#
# File ~\Documents\Universidad\Aprendizaje-Automatico\Practicas\Practica5\ann.py:101, in train_neural_network(X, y, input_size, hidden_size, output_size, lambda_, alpha, num_iterations)
# ...
